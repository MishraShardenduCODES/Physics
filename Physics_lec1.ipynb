# %% [markdown]
# <a href="https://colab.research.google.com/github/MishraShardenduCODES/Physics/blob/main/Physics_lec1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pylab as py

# %%
x=np.array([1,2,3,4,5])
y=x**2

# %%
py.plot(x,y,'r-')

# %%
py.plot(x,y,'r--')

# %%
py.plot(x,y,'r-.')

# %%
py.plot(x,y,'r:')

# %%
py.plot(x,y,'b-')

# %%
py.plot(x,y,'k-')

# %%
py.plot(x,y,'y-')

# %%
py.plot(x,y,'k+')

# %%
py.plot(x,y,'k*')

# %%
py.plot(x,y,'k-')

# %%
py.plot(x,y,'kd')

# %%
py.plot(x,y,'kD')

# %%
py.plot(x,y,'k.')

# %%
py.plot(x,y,'ko')

# %%
py.plot(x,y,'k,')

# %%
py.legend(['time','date'],loc="upper left")
py.title("Practice")
py.xlabel("Date")
py.ylabel("Time")
py.plot(x,y,'g-')
